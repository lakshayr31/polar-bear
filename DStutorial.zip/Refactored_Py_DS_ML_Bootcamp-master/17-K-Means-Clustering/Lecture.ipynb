# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
 from sklearn.datasets import make_blobs

# %%
 data = make_blobs(n_samples=[10,15,20,25],n_features=2,centers=None,cluster_std=4,random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=6)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=6, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ 1.04500665,  8.13968576],
#        [-9.46941837, -6.56081545],
#        [-0.47460595,  3.94782751],
#        [-4.67940744,  7.98950994],
#        [ 4.89844307,  6.54402699],
#        [ 0.3431125 ,  0.55386311]])

# %%
kmeans.labels_
# Out:
# array([3, 4, 2, 0, 4, 1, 0, 5, 0, 2, 3, 2, 0, 4, 3, 5, 4, 5, 1, 3, 1, 5,
#        2, 1, 3, 1, 1, 5, 4, 4, 3, 1, 4, 5, 2, 3, 1, 1, 1, 5, 1, 3, 0, 3,
#        2, 0, 3, 2, 1, 2, 5, 3, 4, 5, 1, 2, 2, 5, 3, 4, 1, 0, 1, 0, 0, 5,
#        1, 4, 0, 1, 0, 2, 1, 2, 1, 4, 0, 2, 3, 2, 2, 1, 4, 1, 5, 5, 5, 3,
#        2, 1, 1, 1, 1, 2, 2, 1, 4, 3, 1, 4, 2, 1, 2, 5, 0, 2, 1, 4, 1, 1,
#        4, 3, 3, 0, 1, 4, 3, 3, 0, 0, 2, 3, 5, 3, 5, 4, 3, 5, 1, 3, 3, 3,
#        5, 1, 1, 3, 4, 2, 4, 5, 1, 4, 1, 0, 0, 0, 2, 1, 3, 3, 3, 3, 5, 4,
#        5, 3, 2, 0, 4, 5, 4, 5, 2, 3, 1, 3, 2, 4, 3, 5, 4, 5, 3, 0, 2, 3,
#        4, 0, 1, 0, 3, 1, 1, 0, 1, 1, 1, 1, 1, 5, 1, 4, 4, 3, 1, 2, 4, 4,
#        1, 5])

# %%
fig, (ax1,ax2) = plt.subplots(1,2,sharey=True,figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('K Means')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
